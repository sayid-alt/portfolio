# %% [markdown]
# <a href="https://colab.research.google.com/github/sayid-alt/olist-store-analysis-project/blob/main/notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Proyek Analisis Data: [Brazilian E-Commerce Public Dataset by Olist]
# - **Nama:** [Sayid Muhammad Heykal]
# - **Email:** [heykalsayid@gmail.com]
# - **ID Dicoding:** [heykalsayid]

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - How have the sales fluctuated over the last few years?
# - What was the most sold product last year?
# - Where are most customers ordering the product?
# - How RFM analysis?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import urllib
from zipfile import ZipFile
import os

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %% [markdown]
# #### Download and retrieve data from github

# %%
# Download raw file from github

DOWNLOAD_ROOT = 'https://raw.githubusercontent.com/sayid-alt/olist-store-analysis-project/main/'
DATASET_PATH = os.path.join('datasets')
DATASET_URL = DOWNLOAD_ROOT + 'olist-datasets.zip'

def fetch_olist_datasets(dataset_url=DATASET_URL, dataset_path=DATASET_PATH):
  os.makedirs(dataset_path, exist_ok=True)
  zip_path = os.path.join(dataset_path, 'olist-datasets.zip')
  urllib.request.urlretrieve(dataset_url, zip_path)
  with ZipFile(zip_path) as zObject:
    zObject.extractall(path=dataset_path)
    zObject.close()

fetch_olist_datasets()

# %% [markdown]
# #### Load olist dataset

# %%
# function for loading an olist datasets
# return pandas datafram

def load_olist_dataset(csv_name):
  olist_path = os.path.join('datasets', 'olist-datasets')
  csv_file = olist_path + '/' + csv_name
  return pd.read_csv(csv_file)

# %% [markdown]
# #### customers_df

# %%
customers_df = load_olist_dataset('olist_customers_dataset.csv')
customers_df.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %% [markdown]
# #### products_df

# %%
products_df = load_olist_dataset('olist_products_dataset.csv')
products_df.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# 1            1000.0               30.0               18.0              20.0
# 2             154.0               18.0                9.0              15.0
# 3             371.0               26.0                4.0              26.0
# 4             625.0               20.0               17.0              13.0

# %% [markdown]
# #### product_name_translation_df

# %%
product_name_translation_df = load_olist_dataset('product_category_name_translation.csv')
product_name_translation_df.head()
# Out:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %% [markdown]
# #### orders_df

# %%
orders_df = load_olist_dataset('olist_orders_dataset.csv')
orders_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2018-07-26 14:31:00           2018-08-07 15:27:45
# 2          2018-08-08 13:50:00           2018-08-17 18:06:29
# 3          2017-11-22 13:39:59           2017-12-02 00:28:42
# 4          2018-02-14 19:46:34           2018-02-16 18:17:02
#
#   order_estimated_delivery_date
# 0           2017-10-18 00:00:00
# 1           2018-08-13 00:00:00
# 2           2018-09-04 00:00:00
# 3           2017-12-15 00:00:00
# 4           2018-02-26 00:00:00

# %% [markdown]
# #### order_items_df

# %%
order_items_df = load_olist_dataset('olist_order_items_dataset.csv')
order_items_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# 4  2017-02-13 13:57:51  199.90          18.14

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# #### assessing - customers_df

# %%
customers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB

# %%
# drop custoemr_unique_id column
customers_df.drop(columns=['customer_unique_id'], inplace=True)

# %%
customers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 4 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_zip_code_prefix  99441 non-null  int64
#  2   customer_city             99441 non-null  object
#  3   customer_state            99441 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 3.0+ MB

# %%
customers_df.isna().sum()
# Out:
# customer_id                 0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64

# %%
customers_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### assessing - products_df

# %%
products_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32341 non-null  object
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %%
products_df.isna().sum()
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %%
products_df.duplicated().sum()
# Out:
# 0

# %%
products_df.head(10)
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
# 5  41d3672d4792049fa1779bb35283ed13  instrumentos_musicais
# 6  732bd381ad09e530fe0a5f457d81becb             cool_stuff
# 7  2548af3e6e77a690cf3eb6368e9ab61e       moveis_decoracao
# 8  37cc742be07708b53a98702e77a21a02       eletrodomesticos
# 9  8c92109888e8cdf9d66dc7e463025574             brinquedos
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
# 5                 60.0                       745.0                 1.0
# 6                 56.0                      1272.0                 4.0
# 7                 56.0                       184.0                 2.0
# 8                 57.0                       163.0                 1.0
# 9                 36.0                      1156.0                 1.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# 1            1000.0               30.0               18.0              20.0
# 2             154.0               18.0                9.0              15.0
# 3             371.0               26.0                4.0              26.0
# 4             625.0               20.0               17.0              13.0
# 5             200.0               38.0                5.0              11.0
# 6           18350.0               70.0               24.0              44.0
# 7             900.0               40.0                8.0              40.0
# 8             400.0               27.0               13.0              17.0
# 9             600.0               17.0               10.0              12.0

# %% [markdown]
# #### assessing - Products_name_trnslation_df

# %%
product_name_translation_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 2 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   product_category_name          71 non-null     object
#  1   product_category_name_english  71 non-null     object
# dtypes: object(2)
# memory usage: 1.2+ KB

# %%
product_name_translation_df.isna().sum()
# Out:
# product_category_name            0
# product_category_name_english    0
# dtype: int64

# %%
product_name_translation_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### assessing - orders_df

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB

# %%
orders_df.isna().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %%
orders_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### assessing - order_items_df

# %%
order_items_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  object
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB

# %%
order_items_df.isna().sum()
# Out:
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64

# %%
order_items_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# #### cleaning - product_df

# %%
products_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32341 non-null  object
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %%
# Rename typo columns name
products_df.rename(columns={
    'product_name_lenght' : 'product_name_length',
    'product_description_lenght' : 'product_description_length'
}, inplace=True)

# %%
# re-check renamed columns
products_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32341 non-null  object
#  2   product_name_length         32341 non-null  float64
#  3   product_description_length  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %%
# imputing missing value with unknown instead of deleting the intire columns
products_df['product_category_name'].fillna('unknown', inplace=True)

# Imputing missing value of numerical columns data with 0
numerical_columns = ['product_name_length', 'product_description_length', 'product_photos_qty', 'product_weight_g', 'product_length_cm', 'product_height_cm', 'product_width_cm']
for col in numerical_columns:
  products_df[col].fillna(0, inplace=True)

# %%
products_df.isna().sum()
# Out:
# product_id                    0
# product_category_name         0
# product_name_length           0
# product_description_length    0
# product_photos_qty            0
# product_weight_g              0
# product_length_cm             0
# product_height_cm             0
# product_width_cm              0
# dtype: int64

# %% [markdown]
# #### cleaning - orders_df

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB

# %%
# change format date
datetime_columns = ['order_purchase_timestamp', 'order_approved_at', 'order_delivered_carrier_date', 'order_delivered_customer_date', 'order_estimated_delivery_date']
for column in datetime_columns:
  orders_df[column] = pd.to_datetime(orders_df[column]).dt.date

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB

# %%
orders_df.isna().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %%
# look up the null value of order_approved_at column
orders_df[orders_df['order_approved_at'].isna()].head()
# Out:
#                               order_id                       customer_id  \
# 1130  00b1cb0320190ca0daa2c88b35206009  3532ba38a3fd242259a514ac2b6ae6b6
# 1801  ed3efbd3a87bea76c2812c66a0b32219  191984a8ba4cbb2145acb4fe35b69664
# 1868  df8282afe61008dc26c6c31011474d02  aa797b187b5466bc6925aaaa4bb3bed1
# 2029  8d4c637f1accf7a88a4555f02741e606  b1dd715db389a2077f43174e7a675d07
# 2161  7a9d4c7f9b068337875b95465330f2fc  7f71ae48074c0cfec9195f88fcbfac55
#
#      order_status order_purchase_timestamp order_approved_at  \
# 1130     canceled               2018-08-28               NaT
# 1801     canceled               2018-09-20               NaT
# 1868     canceled               2017-03-04               NaT
# 2029     canceled               2018-08-29               NaT
# 2161     canceled               2017-05-01               NaT
#
#      order_delivered_carrier_date order_delivered_customer_date  \
# 1130                          NaT                           NaT
# 1801                          NaT                           NaT
# 1868                          NaT                           NaT
# 2029                          NaT                           NaT
# 2161                          NaT                           NaT
#
#      order_estimated_delivery_date
# 1130                    2018-09-12
# 1801                    2018-10-17
# 1868                    2017-04-10
# 2029                    2018-09-13
# 2161                    2017-05-30

# %%
# look up the value counts of order_status column respected to the misisng value of order_approved_at column
orders_df[orders_df['order_approved_at'].isna()]['order_status'].value_counts()
# Out:
# canceled     141
# delivered     14
# created        5
# Name: order_status, dtype: int64

# %%
# print all status order
orders_df['order_status'].value_counts()
# Out:
# delivered      96478
# shipped         1107
# canceled         625
# unavailable      609
# invoiced         314
# processing       301
# created            5
# approved           2
# Name: order_status, dtype: int64

# %%
# drop all rows that does not contains value delivered, because we just want the column that informs us delivered product
orders_df = orders_df[orders_df['order_status'].str.contains('delivered') == True]

# %%
orders_df['order_status'].value_counts() # now it's left column that contains delivered status, it reduces the number of missing values
# Out:
# delivered    96478
# Name: order_status, dtype: int64

# %%
orders_df.isna().sum() # now it lefts missing value with delivered status
# Out:
# order_id                          0
# customer_id                       0
# order_status                      0
# order_purchase_timestamp          0
# order_approved_at                14
# order_delivered_carrier_date      2
# order_delivered_customer_date     8
# order_estimated_delivery_date     0
# dtype: int64

# %%
orders_df[orders_df['order_approved_at'].isna()].head()
# Out:
#                                order_id                       customer_id  \
# 5323   e04abd8149ef81b95221e88f6ed9ab6a  2127dc6603ac33544953ef05ec155771
# 16567  8a9adc69528e1001fc68dd0aaebbb54a  4c1ccc74e00993733742a3c786dc3c1f
# 19031  7013bcfc1c97fe719a7b5e05e61c12db  2941af76d38100e0f8740a374f1a5dc3
# 22663  5cf925b116421afa85ee25e99b4c34fb  29c35fc91fc13fb5073c8f30505d860d
# 23156  12a95a3c06dbaec84bcfb0e2da5d228a  1e101e0daffaddce8159d25a8e53f2b2
#
#       order_status order_purchase_timestamp order_approved_at  \
# 5323     delivered               2017-02-18               NaT
# 16567    delivered               2017-02-18               NaT
# 19031    delivered               2017-02-18               NaT
# 22663    delivered               2017-02-18               NaT
# 23156    delivered               2017-02-17               NaT
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# 5323                    2017-02-23                    2017-03-01
# 16567                   2017-02-23                    2017-03-02
# 19031                   2017-02-22                    2017-03-01
# 22663                   2017-02-22                    2017-03-09
# 23156                   2017-02-22                    2017-03-02
#
#       order_estimated_delivery_date
# 5323                     2017-03-17
# 16567                    2017-03-21
# 19031                    2017-03-17
# 22663                    2017-03-31
# 23156                    2017-03-20

# %%
# count the median value of the gap of order_purchase_timestamp and order_approved_at,
# then the median value will imputed to the order_apporved_at with calculation (order_puchase_timestamp + median gap)
import statistics
median_approved_time = statistics.median(
    orders_df['order_approved_at'] - orders_df['order_purchase_timestamp']
)

orders_df['order_approved_at'].fillna(
    orders_df['order_purchase_timestamp'] + median_approved_time, inplace=True
)

# %%
orders_df.isna().sum()
# Out:
# order_id                         0
# customer_id                      0
# order_status                     0
# order_purchase_timestamp         0
# order_approved_at                0
# order_delivered_carrier_date     2
# order_delivered_customer_date    8
# order_estimated_delivery_date    0
# dtype: int64

# %%
orders_df[orders_df['order_delivered_carrier_date'].isna()]
# Out:
#                                order_id                       customer_id  \
# 73222  2aa91108853cecb43c84a5dc5b277475  afeb16c7f46396c0ed54acb45ccaaa40
# 92643  2d858f451373b04fb5c984a1cc2defaf  e08caf668d499a6d643dafd7c5cc498a
#
#       order_status order_purchase_timestamp order_approved_at  \
# 73222    delivered               2017-09-29        2017-09-29
# 92643    delivered               2017-05-25        2017-05-25
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# 73222                          NaT                    2017-11-20
# 92643                          NaT                           NaT
#
#       order_estimated_delivery_date
# 73222                    2017-11-14
# 92643                    2017-06-23

# %%
# calculate the median value gap between estimated delivery and delivered customer
median_estimated_gap_time = statistics.median(orders_df['order_estimated_delivery_date'] - orders_df['order_delivered_customer_date'])


# now subtract estimated value with median_estimated_gap,
# and impute it to order_delivered_customer_date column
orders_df['order_delivered_customer_date'].fillna(
    orders_df['order_estimated_delivery_date'] - median_estimated_gap_time,
    inplace=True
)

# %%
# calculate median of sum of delivered gap time
median_delivered_time = statistics.median(orders_df['order_delivered_customer_date'] - orders_df['order_delivered_carrier_date'])

# impute the median of gap time value to the missing value in column order_delivered_carrier_date
# by calculating (order_delivered_custoemr_date - median_delivered_time)
orders_df['order_delivered_carrier_date'].fillna(
    orders_df['order_delivered_customer_date'] - median_delivered_time,
    inplace=True
)

# and for missing value in order_delivered_customer_date
# also impute by the same median value calculated by (order_delivered_carrier_date + median_delivered_time)
orders_df['order_delivered_customer_date'].fillna(
    orders_df['order_delivered_carrier_date'] + median_delivered_time,
    inplace=True
)

# %%
orders_df.isna().sum() # all clean
# Out:
# order_id                         0
# customer_id                      0
# order_status                     0
# order_purchase_timestamp         0
# order_approved_at                0
# order_delivered_carrier_date     0
# order_delivered_customer_date    0
# order_estimated_delivery_date    0
# dtype: int64

# %% [markdown]
# #### cleaning - orders_item_df

# %%
order_items_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  object
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB

# %%
order_items_df['shipping_limit_date'] = pd.to_datetime(order_items_df['shipping_limit_date'])

# %%
order_items_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  datetime64[ns]
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(3)
# memory usage: 6.0+ MB

# %%
order_items_df.isna().sum()
# Out:
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64

# %%
order_items_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore - cutomers_df

# %%
customers_df.describe(include='all')
# Out:
#                              customer_id  customer_zip_code_prefix  \
# count                              99441              99441.000000
# unique                             99441                       NaN
# top     06b8999e2fba1a1fbc88172c00ba8bc7                       NaN
# freq                                   1                       NaN
# mean                                 NaN              35137.474583
# std                                  NaN              29797.938996
# min                                  NaN               1003.000000
# 25%                                  NaN              11347.000000
# 50%                                  NaN              24416.000000
# 75%                                  NaN              58900.000000
# max                                  NaN              99990.000000
#
#        customer_city customer_state
# count          99441          99441
# unique          4119             27
# top        sao paulo             SP
# freq           15540          41746
# mean             NaN            NaN
# std              NaN            NaN
# min              NaN            NaN
# 25%              NaN            NaN
# 50%              NaN            NaN
# 75%              NaN            NaN
# max              NaN            NaN

# %%
customers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 4 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_zip_code_prefix  99441 non-null  int64
#  2   customer_city             99441 non-null  object
#  3   customer_state            99441 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 3.0+ MB

# %%
customers_df['customer_city'].value_counts().sort_values(ascending=False).head()
# Out:
# sao paulo         15540
# rio de janeiro     6882
# belo horizonte     2773
# brasilia           2131
# curitiba           1521
# Name: customer_city, dtype: int64

# %%
customers_df['customer_city'].value_counts().sort_values(ascending=False).tail()
# Out:
# palmares paulista    1
# pires ferreira       1
# vicente dutra        1
# alagoa nova          1
# eugenio de castro    1
# Name: customer_city, dtype: int64

# %%
customers_df['customer_state'].value_counts().sort_values(ascending=False).head()
# Out:
# SP    41746
# RJ    12852
# MG    11635
# RS     5466
# PR     5045
# Name: customer_state, dtype: int64

# %%
customers_df['customer_state'].value_counts().sort_values(ascending=False).tail()
# Out:
# RO    253
# AM    148
# AC     81
# AP     68
# RR     46
# Name: customer_state, dtype: int64

# %% [markdown]
# ### Explore - products_df

# %%
products_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32951 non-null  object
#  2   product_name_length         32951 non-null  float64
#  3   product_description_length  32951 non-null  float64
#  4   product_photos_qty          32951 non-null  float64
#  5   product_weight_g            32951 non-null  float64
#  6   product_length_cm           32951 non-null  float64
#  7   product_height_cm           32951 non-null  float64
#  8   product_width_cm            32951 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %%
products_df.describe(include='all')
# Out:
#                               product_id product_category_name  \
# count                              32951                 32951
# unique                             32951                    74
# top     1e9e8ef04dbcff4541ed26657ea517e5       cama_mesa_banho
# freq                                   1                  3029
# mean                                 NaN                   NaN
# std                                  NaN                   NaN
# min                                  NaN                   NaN
# 25%                                  NaN                   NaN
# 50%                                  NaN                   NaN
# 75%                                  NaN                   NaN
# max                                  NaN                   NaN
#
#         product_name_length  product_description_length  product_photos_qty  \
# count          32951.000000                32951.000000        32951.000000
# unique                  NaN                         NaN                 NaN
# top                     NaN                         NaN                 NaN
# freq                    NaN                         NaN                 NaN
# mean              47.579527                  757.213104            2.148463
# std               12.071951                  637.745057            1.745732
# min                0.000000                    0.000000            0.000000
# 25%               41.000000                  326.000000            1.000000
# 50%               51.000000                  584.000000            1.000000
# 75%               57.000000                  961.000000            3.000000
# max               76.000000                 3992.000000           20.000000
#
#         product_weight_g  product_length_cm  product_height_cm  \
# count       32951.000000       32951.000000       32951.000000
# unique               NaN                NaN                NaN
# top                  NaN                NaN                NaN
# freq                 NaN                NaN                NaN
# mean         2276.334315          30.813207          16.936633
# std          4281.945502          16.915648          13.637779
# min             0.000000           0.000000           0.000000
# 25%           300.000000          18.000000           8.000000
# 50%           700.000000          25.000000          13.000000
# 75%          1900.000000          38.000000          21.000000
# max         40425.000000         105.000000         105.000000
#
#         product_width_cm
# count       32951.000000
# unique               NaN
# top                  NaN
# freq                 NaN
# mean           23.195320
# std            12.080033
# min             0.000000
# 25%            15.000000
# 50%            20.000000
# 75%            30.000000
# max           118.000000

# %%
products_df.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_length  product_description_length  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# 1            1000.0               30.0               18.0              20.0
# 2             154.0               18.0                9.0              15.0
# 3             371.0               26.0                4.0              26.0
# 4             625.0               20.0               17.0              13.0

# %% [markdown]
# ### explore - product_name_translation_df

# %%
product_name_translation_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 2 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   product_category_name          71 non-null     object
#  1   product_category_name_english  71 non-null     object
# dtypes: object(2)
# memory usage: 1.2+ KB

# %%
product_name_translation_df.describe(include='all')
# Out:
#        product_category_name product_category_name_english
# count                     71                            71
# unique                    71                            71
# top             beleza_saude                 health_beauty
# freq                       1                             1

# %%
product_name_translation_df.head()
# Out:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %% [markdown]
# ##### create products_translated_df

# %%
# merge products dataframe with product_name_translation dataframe
# this merge aimed for give the translation of category name brazilian with english

products_translated_df = pd.merge(
    left=products_df,
    right=product_name_translation_df,
    how='left',
    left_on='product_category_name',
    right_on='product_category_name'
)

# %%
products_translated_df.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_length  product_description_length  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm  \
# 0             225.0               16.0               10.0              14.0
# 1            1000.0               30.0               18.0              20.0
# 2             154.0               18.0                9.0              15.0
# 3             371.0               26.0                4.0              26.0
# 4             625.0               20.0               17.0              13.0
#
#   product_category_name_english
# 0                     perfumery
# 1                           art
# 2                sports_leisure
# 3                          baby
# 4                    housewares

# %% [markdown]
# ### explore - orders_df & order_items_df

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 96478 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       96478 non-null  object
#  1   customer_id                    96478 non-null  object
#  2   order_status                   96478 non-null  object
#  3   order_purchase_timestamp       96478 non-null  object
#  4   order_approved_at              96478 non-null  object
#  5   order_delivered_carrier_date   96478 non-null  object
#  6   order_delivered_customer_date  96478 non-null  object
#  7   order_estimated_delivery_date  96478 non-null  object
# dtypes: object(8)
# memory usage: 6.6+ MB

# %%
orders_df.describe(include='all')
# Out:
#                                 order_id                       customer_id  \
# count                              96478                             96478
# unique                             96478                             96478
# top     e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# freq                                   1                                 1
#
#        order_status order_purchase_timestamp order_approved_at  \
# count         96478                    96478             96478
# unique            1                      612               609
# top       delivered               2017-11-24        2018-04-24
# freq          96478                     1147               976
#
#        order_delivered_carrier_date order_delivered_customer_date  \
# count                         96478                         96478
# unique                          546                           645
# top                      2017-11-28                    2018-08-27
# freq                            701                           446
#
#        order_estimated_delivery_date
# count                          96478
# unique                           445
# top                       2017-12-20
# freq                             507

# %%
# calculate total delivery time in days
delivery_time = orders_df['order_delivered_customer_date'] - orders_df['order_purchase_timestamp']
delivery_time = delivery_time.apply(lambda x : x.total_seconds())
orders_df['delivery_time'] = round(delivery_time/84000) # divide by 84000 which total second in days

# %%
orders_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp order_approved_at  \
# 0    delivered               2017-10-02        2017-10-02
# 1    delivered               2018-07-24        2018-07-26
# 2    delivered               2018-08-08        2018-08-08
# 3    delivered               2017-11-18        2017-11-18
# 4    delivered               2018-02-13        2018-02-13
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0                   2017-10-04                    2017-10-10
# 1                   2018-07-26                    2018-08-07
# 2                   2018-08-08                    2018-08-17
# 3                   2017-11-22                    2017-12-02
# 4                   2018-02-14                    2018-02-16
#
#   order_estimated_delivery_date  delivery_time
# 0                    2017-10-18            8.0
# 1                    2018-08-13           14.0
# 2                    2018-09-04            9.0
# 3                    2017-12-15           14.0
# 4                    2018-02-26            3.0

# %%
print('delivery time average:', round(orders_df['delivery_time'].mean()), 'days') # count average of total delivery
# Out:
# delivery time average: 13 days

# %%
# create column contains purchase time with format yyyy-mm
orders_df['purchase_year'] = orders_df['order_purchase_timestamp'].apply(lambda x : x.strftime('%Y'))
orders_df['purchase_month'] = orders_df['order_purchase_timestamp'].apply(lambda x : x.strftime('%B'))
orders_df['purchase_year_month'] = orders_df['order_purchase_timestamp'].apply(lambda x : x.strftime('%Y-%m'))

# %%
orders_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp order_approved_at  \
# 0    delivered               2017-10-02        2017-10-02
# 1    delivered               2018-07-24        2018-07-26
# 2    delivered               2018-08-08        2018-08-08
# 3    delivered               2017-11-18        2017-11-18
# 4    delivered               2018-02-13        2018-02-13
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0                   2017-10-04                    2017-10-10
# 1                   2018-07-26                    2018-08-07
# 2                   2018-08-08                    2018-08-17
# 3                   2017-11-22                    2017-12-02
# 4                   2018-02-14                    2018-02-16
#
#   order_estimated_delivery_date  delivery_time purchase_year purchase_month  \
# 0                    2017-10-18            8.0          2017        October
# 1                    2018-08-13           14.0          2018           July
# 2                    2018-09-04            9.0          2018         August
# 3                    2017-12-15           14.0          2017       November
# 4                    2018-02-26            3.0          2018       February
#
#   purchase_year_month
# 0             2017-10
# 1             2018-07
# 2             2018-08
# 3             2017-11
# 4             2018-02

# %% [markdown]
# ##### create order_customers_df

# %%
# merge orders_df with customers_df
order_customers_df = pd.merge(
    left=orders_df,
    right=customers_df,
    how='left',
    left_on='customer_id',
    right_on='customer_id'
)

# %%
order_customers_df = pd.merge(
    left=order_customers_df,
    right=order_items_df,
    how='left',
    left_on='order_id',
    right_on='order_id'
)

# %%
order_customers_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp order_approved_at  \
# 0    delivered               2017-10-02        2017-10-02
# 1    delivered               2018-07-24        2018-07-26
# 2    delivered               2018-08-08        2018-08-08
# 3    delivered               2017-11-18        2017-11-18
# 4    delivered               2018-02-13        2018-02-13
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0                   2017-10-04                    2017-10-10
# 1                   2018-07-26                    2018-08-07
# 2                   2018-08-08                    2018-08-17
# 3                   2017-11-22                    2017-12-02
# 4                   2018-02-14                    2018-02-16
#
#   order_estimated_delivery_date  delivery_time purchase_year  ...  \
# 0                    2017-10-18            8.0          2017  ...
# 1                    2018-08-13           14.0          2018  ...
# 2                    2018-09-04            9.0          2018  ...
# 3                    2017-12-15           14.0          2017  ...
# 4                    2018-02-26            3.0          2018  ...
#
#   purchase_year_month customer_zip_code_prefix            customer_city  \
# 0             2017-10                     3149                sao paulo
# 1             2018-07                    47813                barreiras
# 2             2018-08                    75265               vianopolis
# 3             2017-11                    59296  sao goncalo do amarante
# 4             2018-02                     9195              santo andre
#
#   customer_state order_item_id                        product_id  \
# 0             SP             1  87285b34884572647811a353c7ac498a
# 1             BA             1  595fac2a385ac33a80bd5114aec74eb8
# 2             GO             1  aa4383b373c6aca5d8797843e5594415
# 3             RN             1  d0b61bfb1de832b15ba9d266ca96e5b0
# 4             SP             1  65266b2da20d04dbe00c5c2d3bb7859e
#
#                           seller_id shipping_limit_date   price  freight_value
# 0  3504c0cb71d7fa48d967e0e4c94d59d9 2017-10-06 11:07:15   29.99           8.72
# 1  289cdb325fb7e7f891c38608bf9e0962 2018-07-30 03:24:27  118.70          22.76
# 2  4869f7a5dfa277a7dca6462dcf3b52b2 2018-08-13 08:55:23  159.90          19.22
# 3  66922902710d126a0e7d26b0e3805106 2017-11-23 19:45:59   45.00          27.20
# 4  2c9e548be18521d1c43cde1c582c6de8 2018-02-19 20:31:37   19.90           8.72
#
# [5 rows x 21 columns]

# %%
# total number of orders in spesific year and month
order_customers_df.groupby(by=['purchase_year', 'purchase_month'],  as_index=False).agg({
    'order_id' : 'nunique',
    'price' : 'sum'
})
# Out:
#    purchase_year purchase_month  order_id      price
# 0           2016       December         1      10.90
# 1           2016        October       265   40325.11
# 2           2016      September         1     134.97
# 3           2017          April      2303  340669.68
# 4           2017         August      4193  554699.70
# 5           2017       December      5513  726033.19
# 6           2017       February      1653  234223.40
# 7           2017        January       750  111798.36
# 8           2017           July      3872  481604.52
# 9           2017           June      3135  421923.37
# 10          2017          March      2546  359198.85
# 11          2017            May      3546  489338.25
# 12          2017       November      7289  987765.37
# 13          2017        October      4478  648247.65
# 14          2017      September      4150  607399.67
# 15          2018          April      6798  973534.09
# 16          2018         August      6351  838576.64
# 17          2018       February      6555  826437.13
# 18          2018        January      7069  924645.00
# 19          2018           July      6159  867953.46
# 20          2018           June      6099  856077.86
# 21          2018          March      7003  953356.25
# 22          2018            May      6749  977544.69

# %%
# total number of orders in spesific month
order_customers_df.groupby(by=['purchase_month'],  as_index=False).agg({
    'order_id' : 'nunique',
    'price' : 'sum'
}).sort_values(by='order_id', ascending=False)
# Out:
#    purchase_month  order_id       price
# 1          August     10544  1393276.34
# 8             May     10295  1466882.94
# 5            July     10031  1349557.98
# 7           March      9549  1312555.10
# 6            June      9234  1278001.23
# 0           April      9101  1314203.77
# 3        February      8208  1060660.53
# 4         January      7819  1036443.36
# 9        November      7289   987765.37
# 2        December      5514   726044.09
# 10        October      4743   688572.76
# 11      September      4151   607534.64

# %%
# total number of orders in spesific year
order_customers_df.groupby(by=['purchase_year'],  as_index=False).agg({
    'order_id' : 'nunique',
    'price' : 'sum'
}).sort_values(by='order_id', ascending=False)
# Out:
#   purchase_year  order_id       price
# 2          2018     52783  7218125.12
# 1          2017     43428  5962902.01
# 0          2016       267    40470.98

# %%
# top total number of orders in spesific city
order_customers_df.groupby(by=['customer_city'],  as_index=False).agg({
    'order_id' : 'nunique',
    'price' : 'sum'
}).sort_values(by='order_id', ascending=False)
# Out:
#            customer_city  order_id       price
# 3563           sao paulo     15045  1859556.83
# 3126      rio de janeiro      6601   955573.97
# 449       belo horizonte      2697   346039.04
# 553             brasilia      2071   295814.72
# 1135            curitiba      1489   205999.33
# ...                  ...       ...         ...
# 2924            populina         1       47.60
# 2923          ponto novo         1      360.00
# 2921  ponto do marambaia         1       13.70
# 2920          ponto belo         1       79.90
# 3079        retirolandia         1       89.90
#
# [4085 rows x 3 columns]

# %%
order_items_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  datetime64[ns]
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(3)
# memory usage: 6.0+ MB

# %%
order_customers_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp order_approved_at  \
# 0    delivered               2017-10-02        2017-10-02
# 1    delivered               2018-07-24        2018-07-26
# 2    delivered               2018-08-08        2018-08-08
# 3    delivered               2017-11-18        2017-11-18
# 4    delivered               2018-02-13        2018-02-13
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0                   2017-10-04                    2017-10-10
# 1                   2018-07-26                    2018-08-07
# 2                   2018-08-08                    2018-08-17
# 3                   2017-11-22                    2017-12-02
# 4                   2018-02-14                    2018-02-16
#
#   order_estimated_delivery_date  delivery_time purchase_year  ...  \
# 0                    2017-10-18            8.0          2017  ...
# 1                    2018-08-13           14.0          2018  ...
# 2                    2018-09-04            9.0          2018  ...
# 3                    2017-12-15           14.0          2017  ...
# 4                    2018-02-26            3.0          2018  ...
#
#   purchase_year_month customer_zip_code_prefix            customer_city  \
# 0             2017-10                     3149                sao paulo
# 1             2018-07                    47813                barreiras
# 2             2018-08                    75265               vianopolis
# 3             2017-11                    59296  sao goncalo do amarante
# 4             2018-02                     9195              santo andre
#
#   customer_state order_item_id                        product_id  \
# 0             SP             1  87285b34884572647811a353c7ac498a
# 1             BA             1  595fac2a385ac33a80bd5114aec74eb8
# 2             GO             1  aa4383b373c6aca5d8797843e5594415
# 3             RN             1  d0b61bfb1de832b15ba9d266ca96e5b0
# 4             SP             1  65266b2da20d04dbe00c5c2d3bb7859e
#
#                           seller_id shipping_limit_date   price  freight_value
# 0  3504c0cb71d7fa48d967e0e4c94d59d9 2017-10-06 11:07:15   29.99           8.72
# 1  289cdb325fb7e7f891c38608bf9e0962 2018-07-30 03:24:27  118.70          22.76
# 2  4869f7a5dfa277a7dca6462dcf3b52b2 2018-08-13 08:55:23  159.90          19.22
# 3  66922902710d126a0e7d26b0e3805106 2017-11-23 19:45:59   45.00          27.20
# 4  2c9e548be18521d1c43cde1c582c6de8 2018-02-19 20:31:37   19.90           8.72
#
# [5 rows x 21 columns]

# %% [markdown]
# ### explore products_df

# %%
products_df = products_translated_df

# %%
products_df.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_length  product_description_length  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm  \
# 0             225.0               16.0               10.0              14.0
# 1            1000.0               30.0               18.0              20.0
# 2             154.0               18.0                9.0              15.0
# 3             371.0               26.0                4.0              26.0
# 4             625.0               20.0               17.0              13.0
#
#   product_category_name_english
# 0                     perfumery
# 1                           art
# 2                sports_leisure
# 3                          baby
# 4                    housewares

# %%
products_df.describe()
# Out:
#        product_name_length  product_description_length  product_photos_qty  \
# count         32951.000000                32951.000000        32951.000000
# mean             47.579527                  757.213104            2.148463
# std              12.071951                  637.745057            1.745732
# min               0.000000                    0.000000            0.000000
# 25%              41.000000                  326.000000            1.000000
# 50%              51.000000                  584.000000            1.000000
# 75%              57.000000                  961.000000            3.000000
# max              76.000000                 3992.000000           20.000000
#
#        product_weight_g  product_length_cm  product_height_cm  \
# count      32951.000000       32951.000000       32951.000000
# mean        2276.334315          30.813207          16.936633
# std         4281.945502          16.915648          13.637779
# min            0.000000           0.000000           0.000000
# 25%          300.000000          18.000000           8.000000
# 50%          700.000000          25.000000          13.000000
# 75%         1900.000000          38.000000          21.000000
# max        40425.000000         105.000000         105.000000
#
#        product_width_cm
# count      32951.000000
# mean          23.195320
# std           12.080033
# min            0.000000
# 25%           15.000000
# 50%           20.000000
# 75%           30.000000
# max          118.000000

# %%
# identify weight of product (< 1000 g is small unit, > 1000 g is large unit)
products_df['weight_type'] = products_df['product_weight_g'].apply(lambda x : 'Small' if x < 1000 else 'Large')

# %%
products_df.sample(10)
# Out:
#                              product_id             product_category_name  \
# 10116  98f129cbe241892b96fca3363f2caed4  construcao_ferramentas_seguranca
# 18144  605d9e1329e4d2e960090c8da53d9c86                        perfumaria
# 15141  9592ad22708397a628e1a616131ebbad                  moveis_decoracao
# 13641  2c612d9f04a4e74f68ce85d201c704e8                     esporte_lazer
# 377    769cc5a32d4e6c7710013f35a73d45e9                     esporte_lazer
# 4191   d3ceda8c68fb31960dab19adf28e5c6d                  moveis_decoracao
# 27463  7830940a7e1e18bb7e59e112bca98d1e                     esporte_lazer
# 32465  f5765f6aff97015236abc132d8983b89                  moveis_decoracao
# 31102  abf78d4fed73c782bad7e6ca7a03e7d0            informatica_acessorios
# 19595  3509901ff64b893ac034805e4ebc7dd6             utilidades_domesticas
#
#        product_name_length  product_description_length  product_photos_qty  \
# 10116                 59.0                      2112.0                 5.0
# 18144                 56.0                      1187.0                 2.0
# 15141                 31.0                       335.0                 2.0
# 13641                 45.0                      2578.0                 1.0
# 377                   61.0                       211.0                 4.0
# 4191                  60.0                      2010.0                 2.0
# 27463                 47.0                       481.0                 1.0
# 32465                 58.0                       646.0                 1.0
# 31102                 57.0                      1787.0                 2.0
# 19595                 58.0                      1135.0                 1.0
#
#        product_weight_g  product_length_cm  product_height_cm  \
# 10116             300.0               17.0                7.0
# 18144             500.0               16.0               19.0
# 15141             900.0               30.0                8.0
# 13641             950.0               26.0               25.0
# 377              1100.0               32.0                5.0
# 4191             3000.0               69.0               11.0
# 27463             300.0               16.0               16.0
# 32465             300.0               16.0               30.0
# 31102             100.0               60.0               16.0
# 19595           16950.0               43.0               68.0
#
#        product_width_cm product_category_name_english weight_type
# 10116              17.0     construction_tools_safety       Small
# 18144              16.0                     perfumery       Small
# 15141              23.0               furniture_decor       Small
# 13641              22.0                sports_leisure       Small
# 377                30.0                sports_leisure       Large
# 4191               11.0               furniture_decor       Large
# 27463              11.0                sports_leisure       Small
# 32465              20.0               furniture_decor       Small
# 31102              11.0         computers_accessories       Small
# 19595              41.0                    housewares       Large

# %%
# quantity of large and small product
products_df.groupby('weight_type').product_id.nunique()
# Out:
# weight_type
# Large    13400
# Small    19551
# Name: product_id, dtype: int64

# %%
# number of total sold products
products_df['product_category_name_english'].value_counts()
# Out:
# bed_bath_table               3029
# sports_leisure               2867
# furniture_decor              2657
# health_beauty                2444
# housewares                   2335
#                              ...
# tablets_printing_image          9
# fashion_childrens_clothes       5
# home_comfort_2                  5
# security_and_services           2
# cds_dvds_musicals               1
# Name: product_category_name_english, Length: 71, dtype: int64

# %% [markdown]
# #### create all_df

# %%
all_df = pd.merge(
    left=order_customers_df,
    right=products_df,
    how='left',
    left_on='product_id',
    right_on='product_id'
)

# %%
all_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp order_approved_at  \
# 0    delivered               2017-10-02        2017-10-02
# 1    delivered               2018-07-24        2018-07-26
# 2    delivered               2018-08-08        2018-08-08
# 3    delivered               2017-11-18        2017-11-18
# 4    delivered               2018-02-13        2018-02-13
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0                   2017-10-04                    2017-10-10
# 1                   2018-07-26                    2018-08-07
# 2                   2018-08-08                    2018-08-17
# 3                   2017-11-22                    2017-12-02
# 4                   2018-02-14                    2018-02-16
#
#   order_estimated_delivery_date  delivery_time purchase_year  ...  \
# 0                    2017-10-18            8.0          2017  ...
# 1                    2018-08-13           14.0          2018  ...
# 2                    2018-09-04            9.0          2018  ...
# 3                    2017-12-15           14.0          2017  ...
# 4                    2018-02-26            3.0          2018  ...
#
#    product_category_name product_name_length  product_description_length  \
# 0  utilidades_domesticas                40.0                       268.0
# 1             perfumaria                29.0                       178.0
# 2             automotivo                46.0                       232.0
# 3               pet_shop                59.0                       468.0
# 4              papelaria                38.0                       316.0
#
#   product_photos_qty product_weight_g  product_length_cm product_height_cm  \
# 0                4.0            500.0               19.0               8.0
# 1                1.0            400.0               19.0              13.0
# 2                1.0            420.0               24.0              19.0
# 3                3.0            450.0               30.0              10.0
# 4                4.0            250.0               51.0              15.0
#
#   product_width_cm product_category_name_english  weight_type
# 0             13.0                    housewares        Small
# 1             19.0                     perfumery        Small
# 2             21.0                          auto        Small
# 3             20.0                      pet_shop        Small
# 4             15.0                    stationery        Small
#
# [5 rows x 31 columns]

# %%
all_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 110197 entries, 0 to 110196
# Data columns (total 31 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       110197 non-null  object
#  1   customer_id                    110197 non-null  object
#  2   order_status                   110197 non-null  object
#  3   order_purchase_timestamp       110197 non-null  object
#  4   order_approved_at              110197 non-null  object
#  5   order_delivered_carrier_date   110197 non-null  object
#  6   order_delivered_customer_date  110197 non-null  object
#  7   order_estimated_delivery_date  110197 non-null  object
#  8   delivery_time                  110197 non-null  float64
#  9   purchase_year                  110197 non-null  object
#  10  purchase_month                 110197 non-null  object
#  11  purchase_year_month            110197 non-null  object
#  12  customer_zip_code_prefix       110197 non-null  int64
#  13  customer_city                  110197 non-null  object
#  14  customer_state                 110197 non-null  object
#  15  order_item_id                  110197 non-null  int64
#  16  product_id                     110197 non-null  object
#  17  seller_id                      110197 non-null  object
#  18  shipping_limit_date            110197 non-null  datetime64[ns]
#  19  price                          110197 non-null  float64
#  20  freight_value                  110197 non-null  float64
#  21  product_category_name          110197 non-null  object
#  22  product_name_length            110197 non-null  float64
#  23  product_description_length     110197 non-null  float64
#  24  product_photos_qty             110197 non-null  float64
#  25  product_weight_g               110197 non-null  float64
#  26  product_length_cm              110197 non-null  float64
#  27  product_height_cm              110197 non-null  float64
#  28  product_width_cm               110197 non-null  float64
#  29  product_category_name_english  108638 non-null  object
#  30  weight_type                    110197 non-null  object
# dtypes: datetime64[ns](1), float64(10), int64(2), object(18)
# memory usage: 26.9+ MB

# %%
# most sold products
all_df.groupby(by=['product_category_name_english',]).agg({
    'order_id' : 'nunique',
    'price' : 'sum'
}).sort_values(by='order_id', ascending=False)
# Out:
#                                order_id       price
# product_category_name_english
# bed_bath_table                     9272  1023434.76
# health_beauty                      8647  1233131.72
# sports_leisure                     7530   954852.55
# computers_accessories              6530   888724.61
# furniture_decor                    6307   711927.69
# ...                                 ...         ...
# arts_and_craftmanship                23     1814.01
# la_cuisine                           13     2054.99
# cds_dvds_musicals                    12      730.00
# fashion_childrens_clothes             7      519.95
# security_and_services                 2      283.29
#
# [71 rows x 2 columns]

# %%
# most sold products every years
all_df.groupby(by=['purchase_year', 'product_category_name_english']).agg({
    'order_id': ['nunique'],
    'price' : 'sum'
})
# Out:
#                                             order_id      price
#                                              nunique        sum
# purchase_year product_category_name_english
# 2016          air_conditioning                     4    1349.29
#               audio                                2     156.99
#               auto                                 8    1128.26
#               baby                                 9    1371.17
#               bed_bath_table                       5     478.99
# ...                                              ...        ...
# 2018          stationery                        1367  132315.75
#               tablets_printing_image              20    1267.96
#               telephony                         2117  174123.68
#               toys                              1378  168123.27
#               watches_gifts                     3418  687855.20
#
# [170 rows x 2 columns]

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1: How have the sales fluctuated over the last few years?

# %%
datetime_columns = ['order_purchase_timestamp', 'order_approved_at',
                    'order_delivered_carrier_date', 'order_delivered_customer_date',
                    'order_estimated_delivery_date', 'shipping_limit_date']
for column in datetime_columns:
    all_df[column] = pd.to_datetime(all_df[column])

# %%
daily_orders_df = all_df.resample(rule='D', on='order_purchase_timestamp').agg({
    'order_id' : "nunique",
    'price' : 'sum'
}).reset_index()

# %%
daily_orders_df.rename(columns={
    'order_purchase_timestamp' : 'date',
    'order_id' : 'order_count',
    'price' : 'revenue'
},inplace=True)

daily_orders_df['order_count'].sum()
# Out:
# 96478

# %%
daily_orders_df.sample(5)
# Out:
#           date  order_count   revenue
# 674 2018-07-21          184  20845.68
# 0   2016-09-15            1    134.97
# 481 2018-01-09          246  29865.17
# 538 2018-03-07          254  35398.91
# 44  2016-10-29            0      0.00

# %%
# Show graph of monthly order
fig, ax = plt.subplots(figsize=(16,8))

ax.plot(daily_orders_df['date'], daily_orders_df['revenue'], linewidth=1, color='#863A6F')

plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# ### Pertanyaan 2: What was the most sold product last year?

# %%
# create sample datasets of particular range time
most_product_orders_df = all_df.groupby(by=['product_category_name_english']).agg({
    'order_id' : 'nunique'
}).sort_values(by='order_id', ascending=False).reset_index()

most_product_orders_df.rename(columns={
    'product_category_name_english' : 'category',
    'order_id' : 'category_count'
},inplace=True)

most_product_orders_df
# Out:
#                      category  category_count
# 0              bed_bath_table            9272
# 1               health_beauty            8647
# 2              sports_leisure            7530
# 3       computers_accessories            6530
# 4             furniture_decor            6307
# ..                        ...             ...
# 66      arts_and_craftmanship              23
# 67                 la_cuisine              13
# 68          cds_dvds_musicals              12
# 69  fashion_childrens_clothes               7
# 70      security_and_services               2
#
# [71 rows x 2 columns]

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(15,5))

colors = ['#863A6F','#D3D3D3','#D3D3D3','#D3D3D3','#D3D3D3','#D3D3D3','#D3D3D3','#D3D3D3','#D3D3D3','#D3D3D3','#D3D3D3']

sns.barplot(
    data=most_product_orders_df.sort_values(by='category_count',ascending=False).head(10),
    y='category', x='category_count',
    palette=colors,
    ax=ax[0]
)

ax[0].set_title('The most sold product')
ax[0].set_xlabel(None)
ax[0].set_ylabel(None)

sns.barplot(
    data=most_product_orders_df.sort_values(by='category_count',ascending=True).tail(10),
    y='category', x='category_count',
    palette=colors,
    ax=ax[1]
)

ax[1].set_title('The least sold product')
ax[1].set_xlabel(None)
ax[1].set_ylabel(None)
ax[1].yaxis.set_label_position('right') # set label y axis to the right

# invert xaxis direction
ax[1].invert_xaxis()

# set yaxis label to the right side
ax[1].yaxis.tick_right()
# Out:
# <ipython-input-1282-8f380185bacf>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# <ipython-input-1282-8f380185bacf>:5: UserWarning: The palette list has more values (11) than needed (10), which may not be intended.
#   sns.barplot(
# <ipython-input-1282-8f380185bacf>:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# <ipython-input-1282-8f380185bacf>:16: UserWarning: The palette list has more values (11) than needed (10), which may not be intended.
#   sns.barplot(

# %% [markdown]
# ### Pertanyaan 3: Where are most customers ordering the product?

# %%
order_bycity_df = all_df.groupby(by='customer_city').agg({
    'order_id' : 'nunique',
    'price' : 'sum'
}).sort_values(by='order_id',ascending=False).reset_index()

order_bycity_df.rename(columns={
    'customer_city' : 'city',
    'order_id' : 'order_count',
    'price' : 'revenue'
}, inplace=True)

order_bycity_df
# Out:
#                     city  order_count     revenue
# 0              sao paulo        15045  1859556.83
# 1         rio de janeiro         6601   955573.97
# 2         belo horizonte         2697   346039.04
# 3               brasilia         2071   295814.72
# 4               curitiba         1489   205999.33
# ...                  ...          ...         ...
# 4080            populina            1       47.60
# 4081          ponto novo            1      360.00
# 4082  ponto do marambaia            1       13.70
# 4083          ponto belo            1       79.90
# 4084        retirolandia            1       89.90
#
# [4085 rows x 3 columns]

# %%
colors = ['#863A6F', '#D3D3D3', '#D3D3D3', '#D3D3D3', '#D3D3D3',
          '#D3D3D3', '#D3D3D3', '#D3D3D3', '#D3D3D3', '#D3D3D3', '#D3D3D3']

fig, ax = plt.subplots(figsize=(7,5))
sns.barplot(
    data = order_bycity_df.sort_values(by='order_count', ascending=False).head(10),
    x='city', y = 'order_count',
    palette=colors
)

ax.set_ylabel(None)
ax.set_ylabel(None)
ax.set_title('Number of order by city', fontsize=15)
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-1284-bc6db6c5775d>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# <ipython-input-1284-bc6db6c5775d>:5: UserWarning: The palette list has more values (11) than needed (10), which may not be intended.
#   sns.barplot(

# %% [markdown]
# ### Pertanyaan 4 : How RFM analysis?

# %%
# grouping a columns contain customer_id, max order time, frequency
rfm_df = all_df.groupby('customer_id', as_index=False).agg({
    'order_purchase_timestamp' : 'max',
    'order_id' : 'nunique',
    'price' : 'sum'
})

# %%
# rename columns of rfm
rfm_df.columns = ['customer_id', 'max_order_timestamp', 'frequency', 'monetary']
rfm_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96478 entries, 0 to 96477
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   customer_id          96478 non-null  object
#  1   max_order_timestamp  96478 non-null  datetime64[ns]
#  2   frequency            96478 non-null  int64
#  3   monetary             96478 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(1)
# memory usage: 2.9+ MB

# %%
rfm_df.head()
# Out:
#                         customer_id max_order_timestamp  frequency  monetary
# 0  00012a2ce6f8dcda20d059ce98491703          2017-11-14          1     89.80
# 1  000161a058600d5901f007fab4c27140          2017-07-16          1     54.90
# 2  0001fd6190edaaf884bcaf3d49edf079          2017-02-28          1    179.99
# 3  0002414f95344307404f0ace7a26f1d5          2017-08-16          1    149.90
# 4  000379cdec625522490c315e70c7a9fb          2018-04-02          1     93.00

# %%
# initializing a recent date value from order time
recent_date = orders_df['order_purchase_timestamp'].max()
recent_date
# Out:
# datetime.date(2018, 8, 29)

# %%
# format date
rfm_df['max_order_timestamp'] = rfm_df['max_order_timestamp'].dt.date
rfm_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96478 entries, 0 to 96477
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   customer_id          96478 non-null  object
#  1   max_order_timestamp  96478 non-null  object
#  2   frequency            96478 non-null  int64
#  3   monetary             96478 non-null  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 2.9+ MB

# %%
# calculate recent date of customer order
rfm_df['recency'] = rfm_df['max_order_timestamp'].apply(lambda x : (recent_date - x).days)
rfm_df['customer_number'] = [x+1 for x in range(len(rfm_df))]

# %%
rfm_df.head()
# Out:
#                         customer_id max_order_timestamp  frequency  monetary  \
# 0  00012a2ce6f8dcda20d059ce98491703          2017-11-14          1     89.80
# 1  000161a058600d5901f007fab4c27140          2017-07-16          1     54.90
# 2  0001fd6190edaaf884bcaf3d49edf079          2017-02-28          1    179.99
# 3  0002414f95344307404f0ace7a26f1d5          2017-08-16          1    149.90
# 4  000379cdec625522490c315e70c7a9fb          2018-04-02          1     93.00
#
#    recency  customer_number
# 0      288                1
# 1      409                2
# 2      547                3
# 3      378                4
# 4      149                5

# %%
rfm_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96478 entries, 0 to 96477
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   customer_id          96478 non-null  object
#  1   max_order_timestamp  96478 non-null  object
#  2   frequency            96478 non-null  int64
#  3   monetary             96478 non-null  float64
#  4   recency              96478 non-null  int64
#  5   customer_number      96478 non-null  int64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 4.4+ MB

# %%
rfm_df['recency'].sort_values().head()
# Out:
# 41385    0
# 6220     0
# 31668    0
# 27635    0
# 25785    0
# Name: recency, dtype: int64

# %%
rfm_df['frequency'].sort_values(ascending=False).head()
# Out:
# 0        1
# 64315    1
# 64324    1
# 64323    1
# 64322    1
# Name: frequency, dtype: int64

# %%
rfm_df['monetary'].sort_values(ascending=False).head()
# Out:
# 8293     13440.0
# 89276     7160.0
# 75240     6735.0
# 92311     6729.0
# 24068     6499.0
# Name: monetary, dtype: float64

# %%
fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(30, 6))

colors = ['#FFADBC','#FFADBC','#FFADBC','#FFADBC', '#FFADBC','#FFADBC']


sns.barplot(
    y="recency", x="customer_number",
    data=rfm_df.sort_values(by="recency").head(),
    palette=colors,
    ax=ax[0])

ax[0].set_ylabel(None)
ax[0].set_xlabel(None)
ax[0].set_title("Recency (days)")
ax[0].tick_params(axis ='x', labelsize=15)

sns.barplot(y="frequency", x="customer_number",
            data=rfm_df.sort_values(by="frequency", ascending=False).head(),
            palette=colors,
            ax=ax[1])

ax[1].set_ylabel(None)
ax[1].set_xlabel(None)
ax[1].set_title("By Frequency")
ax[1].tick_params(axis='x', labelsize=15)

sns.barplot(y="monetary",
            x="customer_number",
            data=rfm_df.sort_values(by="monetary", ascending=False).head(),
            palette=colors, ax=ax[2])

ax[2].set_ylabel(None)
ax[2].set_xlabel(None)
ax[2].set_title("Monetary")
ax[2].tick_params(axis='x', labelsize=15)

plt.suptitle("Customer RFM Parameters (customer_number)", fontsize=25)
plt.show()
# Out:
# <ipython-input-1296-30a9a9438634>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# <ipython-input-1296-30a9a9438634>:6: UserWarning: The palette list has more values (6) than needed (5), which may not be intended.
#   sns.barplot(
# <ipython-input-1296-30a9a9438634>:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y="frequency", x="customer_number",
# <ipython-input-1296-30a9a9438634>:17: UserWarning: The palette list has more values (6) than needed (5), which may not be intended.
#   sns.barplot(y="frequency", x="customer_number",
# <ipython-input-1296-30a9a9438634>:27: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y="monetary",
# <ipython-input-1296-30a9a9438634>:27: UserWarning: The palette list has more values (6) than needed (5), which may not be intended.
#   sns.barplot(y="monetary",

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - **Conclution pertanyaan 1**<br>
# Generally sales is more tends to get more higher over the years, and the most sales was shown in date 2017-11
# - **Conclution pertanyaan 2**<br>
# The most sold product category in the last year or 2018, was healty_beuty product as shown in graph, and the least or worst sold product was garder_tools
# - **Conclution pertanyaan 4**<br>
# The most city customer was sao paolo as shown in the graph
# - **Conclution pertanyaan 4**<br>
# Shows that customers recent date order is 0 means it's less than a day, and frequency of customers is mostly once, then the monetary of customer number 8294 is most higher monetary

# %%
all_df.to_csv("all_data.csv", index=False)
